# %%
# !pip install poetry
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 281.6/281.6 kB 6.9 MB/s eta 0:00:00:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 338.6/338.6 kB 12.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.7/78.7 kB 6.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 47.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 453.8/453.8 kB 32.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.1/66.1 kB 4.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.0/6.0 MB 85.0 MB/s eta 0:00:00:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 469.0/469.0 kB 30.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.2/3.2 MB 89.2 MB/s eta 0:00:00:00:01
# ...

# %%
# Clona il repository CodonBERT
# !git clone https://github.com/Sanofi-Public/CodonBERT.git
# Out:
# Cloning into 'CodonBERT'...
# remote: Enumerating objects: 138, done.
# remote: Counting objects: 100% (28/28), done.
# remote: Compressing objects: 100% (13/13), done.
# remote: Enumerating objects: 138, done.
# remote: Counting objects: 100% (28/28), done.
# remote: Compressing objects: 100% (13/13), done.
# remote: Total 138 (delta 16), reused 15 (delta 15), pack-reused 110 (from 1)
# Receiving objects: 100% (138/138), 217.36 MiB | 26.45 MiB/s, done.
# remote: Total 138 (delta 16), reused 15 (delta 15), pack-reused 110 (from 1)
# Receiving objects: 100% (138/138), 217.36 MiB | 26.45 MiB/s, done.
# Resolving deltas: 100% (52/52), done.
# Resolving deltas: 100% (52/52), done.
# Updating files: 100% (42/42), done.
# Updating files: 100% (42/42), done.

# %% [markdown]
# I dataset si troveranno in:
# - **Pre-training**: `CodonBERT/benchmarks/CodonBERT/data/pre-train/`
# - **Fine-tuning**: `CodonBERT/benchmarks/CodonBERT/data/fine-tune/`

# %%
# Importa le librerie necessarie
import pandas as pd
import os

# Esempio: carica un dataset di fine-tuning
dataset_path = "CodonBERT/benchmarks/CodonBERT/data/fine-tune/mRFP_Expression.csv"
if os.path.exists(dataset_path):
    df = pd.read_csv(dataset_path)
    print(f"Dataset shape: {df.shape}")
    print(f"Columns: {df.columns.tolist()}")
    df.head()
# Out:
# Dataset shape: (1459, 4)
# Columns: ['Sequence', 'Value', 'Dataset', 'Split']
